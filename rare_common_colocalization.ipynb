# %% [markdown]
# # rare-common network colocalization

# %% [markdown]
# determine if there's significant network overlap between genes from GWAS (common) and rare variants

# %% [markdown]
# # setup

# %%
#read in libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib_venn import venn2 
import scipy.stats as stats
import matplotlib
from scipy.stats import hypergeom
import ndex2
import networkx as nx
from netcoloc import netprop_zscore
from netcoloc import netprop
from netcoloc import network_colocalization
import os
from rca_functions import *

# %%
matplotlib.rcParams.update({'font.size': 14})

# %%
os.chdir('/tscc/nfs/home/bsleger/bsl/rare_common_alcohol/')

# %%
save_fig=False

cutoff_comb=3
cutoff_single=1.5

# %% [markdown]
# ## Interactome Set-up

# %%
#define user for ndex based on meta file
if os.path.isfile('environ_ndex_meta.py'):
    print ('True')
    from environ_ndex_meta import *
else:
    ndex_user=None
    ndex_password=None
# Out:
# True

# %%
interactome_name='pcnet_v14'
UUIDs #imported from rca_functions
# Out:
# {'pcnet_v14': 'c3554b4e-8c81-11ed-a157-005056ae23aa',
#  'pcnet_v13': '4de852d9-9908-11e9-bcaf-0ac135e8bacf',
#  'string': '98ba6a19-586e-11e7-8f50-0ac135e8bacf',
#  'humanNet_v3_FN': '40913318-3a9c-11ed-ac45-0ac135e8bacf',
#  'pcnet_v20': 'f5767e8b-cdcc-11ee-93f7-005056ae23aa',
#  'ACN': 'f81a3f67-4215-11ee-aa50-005056ae23aa',
#  'ACN2': '3537279e-ceea-11ee-93f7-005056ae23aa'}

# %%
interactome=import_interactome(interactome_name)
interactome_nodes=list(interactome.nodes())
# Out:
# pcnet_v14
# number of nodes:
# 18630
#
# number of edges:
# 2687393

# %% [raw]
# # pre calculate mats used for netprop... this step takes a few minutes, more for denser interactomes
# print('\ncalculating w_prime')
# w_prime = netprop.get_normalized_adjacency_matrix(interactome, conserve_heat=True)
#
# print('\ncalculating w_double_prime')
# w_double_prime = netprop.get_individual_heats_matrix(w_prime, .5)

# %% [markdown]
# # Run looped analysis

# %% [markdown]
# loops through the chosen rare and common datasets to calculate the overlapping network, and subsequent statstical secondary analyses

# %% [markdown]
# ## import metadata for datasets- includes delimiters, column names, file names, etc.

# %%
common_datasets=pd.read_csv('common_datasets_prepub.csv',sep=',')
rare_datasets=pd.read_csv('rare_datasets_prepub.csv',sep=',')

# %% [markdown]
# ### define samples you want to run

# %% [markdown]
# #### common datasets

# %%
common_datasets
# Out:
#               group snp2gene_method                     label phenotype_group  \
# 0         GSCAN_DPW           magma           GSCAN_DPW_magma         alcohol
# 1   ukbb_anyalcohol           magma  ukbb_alcoholintake_magma         alcohol
# 2  neale_20153_irnt           magma    neale_20153_irnt_magma         control
# 3  neale_30110_irnt           magma    neale_30110_irnt_magma         control
# 4   neale_3148_irnt           magma     neale_3148_irnt_magma         control
# 5   neale_4104_irnt           magma     neale_4104_irnt_magma         control
#
#                                            seed_path  delim  \
# 0              GSCAN_DPW/GSCAN_DPW_magma_results.csv  comma
# 1  ukbb_anyalcohol/ukbb_anyalcohol_magma_results.csv  comma
# 2  neale_ctrl/FUMA_ukbb_20153_irnt_neale/magma.ge...    tab
# 3  neale_ctrl/FUMA_ukbb_30110_irnt_neale/magma.ge...    tab
# 4  neale_ctrl/FUMA_ukbb_3148_irnt_neale/magma.gen...    tab
# 5  neale_ctrl/FUMA_ukbb_4104_irnt_neale/magma.gen...    tab
#
#                            zscore_file  \
# 0           gscan_dpw_magma_zscore.tsv
# 1  ukbb_alcoholintake_magma_zscore.tsv
# 2         neale_20153_magma_zscore.tsv
# 3         neale_30110_magma_zscore.tsv
# 4     neale_3148_irnt_magma_zscore.tsv
# 5     neale_4104_irnt_magma_zscore.tsv
#
#                                          zscore_path seed_p seed_gene_name  \
# 0          network_scores/gscan_dpw_magma_zscore.tsv      P      GENE_NAME
# 1  network_scores/ukbb_alcoholintake_magma_zscore...      P      GENE_NAME
# 2        network_scores/neale_20153_magma_zscore.tsv      P         SYMBOL
# 3        network_scores/neale_30110_magma_zscore.tsv      P         SYMBOL
# 4    network_scores/neale_3148_irnt_magma_zscore.tsv      P         SYMBOL
# 5    network_scores/neale_4104_irnt_magma_zscore.tsv      P         SYMBOL
#
#              description      cutoff
# 0  drinks_per_week_gscan  bonferroni
# 1  drinks_per_month_ukbb  bonferroni
# 2                   FEV1  bonferroni
# 3         platelet_width  bonferroni
# 4      heel_bone_density  bonferroni
# 5      heel_bone_density  bonferroni

# %%
#subset datasets from rare variants that you want to analyze
common_datasets=common_datasets[0:1]
common_datasets=common_datasets.reset_index()

# %%
common_datasets
# Out:
#    index      group snp2gene_method            label phenotype_group  \
# 0      0  GSCAN_DPW           magma  GSCAN_DPW_magma         alcohol
#
#                                seed_path  delim                 zscore_file  \
# 0  GSCAN_DPW/GSCAN_DPW_magma_results.csv  comma  gscan_dpw_magma_zscore.tsv
#
#                                  zscore_path seed_p seed_gene_name  \
# 0  network_scores/gscan_dpw_magma_zscore.tsv      P      GENE_NAME
#
#              description      cutoff
# 0  drinks_per_week_gscan  bonferroni

# %%
rare_datasets
# Out:
#                               label  \
# 0              alcoholintake_FDR_25
# 1      rare_neale_20153_irnt_FDR_25
# 2      rare_neale_30110_irnt_FDR_25
# 3           rare_neale_20016_FDR_25
# 4           rare_neale_20502_FDR_25
# 5            rare_neale_2443_FDR_25
# 6            rare_neale_4194_FDR_25
# 7              rare_neale_78_FDR_25
# 8             rare_neale_C50_FDR_25
# 9             rare_neale_C44_FDR_25
# 10         rare_neale_100010_FDR_25
# 11         rare_neale_100016_FDR_25
# 12  rare_strin_allcut_alcoholintake
#
#                                           cutoff used  \
# 0                                 all tests FDR <0.25
# 1                                 all tests FDR <0.25
# 2                                 all tests FDR <0.25
# 3                                 all tests FDR <0.25
# 4                                 all tests FDR <0.25
# 5                                 all tests FDR <0.25
# 6                                 all tests FDR <0.25
# 7                                 all tests FDR <0.25
# 8                                 all tests FDR <0.25
# 9                                 all tests FDR <0.25
# 10                                all tests FDR <0.25
# 11                                all tests FDR <0.25
# 12  burden bonferroni < 0.05 in the whole table of...
#
#                                             seed_path  delim  \
# 0   rare_variant_genebass/alcohol_intake/alcohol_i...  comma
# 1   rare_variant_genebass/20153_irnt/20153_irnt_25...    tab
# 2   rare_variant_genebass/30110_irnt/30110_irnt_25...    tab
# 3         rare_variant_genebass/20016/20016_25FDR.tsv    tab
# 4         rare_variant_genebass/20502/20502_25FDR.tsv    tab
# 5           rare_variant_genebass/2443/2443_25FDR.tsv    tab
# 6           rare_variant_genebass/4194/4194_25FDR.tsv    tab
# 7               rare_variant_genebass/78/78_25FDR.tsv    tab
# 8             rare_variant_genebass/C50/C50_25FDR.tsv    tab
# 9             rare_variant_genebass/C44/C44_25FDR.tsv    tab
# 10      rare_variant_genebass/100010/100010_25FDR.tsv    tab
# 11      rare_variant_genebass/100016/100016_25FDR.tsv    tab
# 12  rare_variant_genebass/alcohol_intake/alcohol_i...  comma
#
#                                    zscore_file  \
# 0              alcoholintake_fdr_25_zscore.tsv
# 1      rare_neale_20153_irnt_fdr_25_zscore.tsv
# 2      rare_neale_30110_irnt_fdr_25_zscore.tsv
# 3           rare_neale_20016_fdr_25_zscore.tsv
# 4           rare_neale_20502_fdr_25_zscore.tsv
# 5            rare_neale_2443_fdr_25_zscore.tsv
# 6            rare_neale_4194_fdr_25_zscore.tsv
# 7              rare_neale_78_fdr_25_zscore.tsv
# 8             rare_neale_c50_fdr_25_zscore.tsv
# 9             rare_neale_c44_fdr_25_zscore.tsv
# 10         rare_neale_100010_fdr_25_zscore.tsv
# 11         rare_neale_100016_fdr_25_zscore.tsv
# 12  rare_strin_allcut_alcoholintake_zscore.tsv
#
#                                           zscore_path  \
# 0      network_scores/alcoholintake_FDR_25_zscore.tsv
# 1   network_scores/rare_neale_20153_irnt_FDR_25_zs...
# 2   network_scores/rare_neale_30110_irnt_FDR_25_zs...
# 3   network_scores/rare_neale_20016_FDR_25_zscore.tsv
# 4   network_scores/rare_neale_20502_FDR_25_zscore.tsv
# 5    network_scores/rare_neale_2443_FDR_25_zscore.tsv
# 6    network_scores/rare_neale_4194_FDR_25_zscore.tsv
# 7      network_scores/rare_neale_78_FDR_25_zscore.tsv
# 8     network_scores/rare_neale_C50_FDR_25_zscore.tsv
# 9     network_scores/rare_neale_C44_FDR_25_zscore.tsv
# 10  network_scores/rare_neale_100010_FDR_25_zscore...
# 11  network_scores/rare_neale_100016_FDR_25_zscore...
# 12  network_scores/rare_strin_allcut_alcoholintake...
#
#                                            Unnamed: 6 seed_gene_name  \
# 0      network_scores/alcoholintake_fdr_25_zscore.tsv      Gene Name
# 1   network_scores/rare_neale_20153_irnt_fdr_25_zs...      Gene Name
# 2   network_scores/rare_neale_30110_irnt_fdr_25_zs...      Gene Name
# 3   network_scores/rare_neale_20016_fdr_25_zscore.tsv      Gene Name
# 4   network_scores/rare_neale_20502_fdr_25_zscore.tsv      Gene Name
# 5    network_scores/rare_neale_2443_fdr_25_zscore.tsv      Gene Name
# 6    network_scores/rare_neale_4194_fdr_25_zscore.tsv      Gene Name
# 7      network_scores/rare_neale_78_fdr_25_zscore.tsv      Gene Name
# 8     network_scores/rare_neale_c50_fdr_25_zscore.tsv      Gene Name
# 9     network_scores/rare_neale_c44_fdr_25_zscore.tsv      Gene Name
# 10  network_scores/rare_neale_100010_fdr_25_zscore...      Gene Name
# 11  network_scores/rare_neale_100016_fdr_25_zscore...      Gene Name
# 12  network_scores/rare_strin_allcut_alcoholintake...    gene_symbol
#
#    phenotype_group
# 0          alcohol
# 1          control
# 2          control
# 3          control
# 4          control
# 5          control
# 6          control
# 7          control
# 8          control
# 9          control
# 10         control
# 11         control
# 12         alcohol

# %%
#subset datasets from rare variants that you want to analyze
rare_datasets=rare_datasets[0:1]
rare_datsets=rare_datasets.reset_index()
rare_datasets
# Out:
#                   label          cutoff used  \
# 0  alcoholintake_FDR_25  all tests FDR <0.25
#
#                                            seed_path  delim  \
# 0  rare_variant_genebass/alcohol_intake/alcohol_i...  comma
#
#                        zscore_file  \
# 0  alcoholintake_fdr_25_zscore.tsv
#
#                                       zscore_path  \
# 0  network_scores/alcoholintake_FDR_25_zscore.tsv
#
#                                        Unnamed: 6 seed_gene_name  \
# 0  network_scores/alcoholintake_fdr_25_zscore.tsv      Gene Name
#
#   phenotype_group
# 0         alcohol

# %% [markdown]
# ## histogram

# %% [markdown]
# generate histograms of the NPS scores from the rare and common datasets, with and without seed genes, combined NPS scores, and scatter plot of NPS scores

# %%
for row_rare in range(len(rare_datasets)):
    #import rare seed gene list and NPS scores
    label_rare=rare_datasets['label'][row_rare]
    print('analyzing rare dataset: '+label_rare)
    seed_rare=import_seedgenes(path=rare_datasets['seed_path'][row_rare],
                               pcol=None,
                               gene_col=rare_datasets['seed_gene_name'],
                                delim=rare_datasets['delim'][row_rare])
    seed_rare=list(set(seed_rare[rare_datasets['seed_gene_name'][row_rare]]))
    zscore_rare_df=import_nps_zscores(z_path=rare_datasets['zscore_path'][row_rare], interactome_name='pcnet_v14')
    for row_common in range(len(common_datasets)):
        label_common=common_datasets['label'][row_common]
        print('analyzing common dataset: '+label_common)
        seed_common=import_seedgenes(path=common_datasets['seed_path'][row_common],
                                    pcol=common_datasets['seed_p'][row_common], 
                                    gene_col=common_datasets['seed_gene_name'][row_common],
                                    delim=common_datasets['delim'][row_common],
                                    cutoff=common_datasets['cutoff'][row_common])
        zscore_common_df=import_nps_zscores(z_path=common_datasets['zscore_path'][row_common], interactome_name='pcnet_v14')

        plt_histogram(zscore_rare_df, zscore_common_df, str(label_rare), str(label_common),seed_rare,seed_common, 1.5, 1.5,3, save_fig)
        plt.clf()
# Out:
# analyzing rare dataset: alcoholintake_FDR_25
# pvalue column not specified- all genes will be used
# cutoff not defined/custom- using all genes
#    Unnamed: 0 Gene Name
# 0           0      PMM2
# 1           1   SLC29A1
# 2           2     SCN7A
# 3           3    ATP2B1
# 4           4     MMEL1
# importing file: network_scores/alcoholintake_fdr_25_zscore.tsv
#                z
# 0
# UBE2Q1 -0.900155
# RNF14  -1.262321
# UBE2Q2 -0.826430
# TMCO1  -1.503556
# UBAC1   0.528793
# analyzing common dataset: GSCAN_DPW_magma
#        GENE  CHR     START      STOP  NSNPS  NPARAM       N   ZSTAT  \
# 202   79814    1  15561699  15595110    199      19  628831  4.9260
# 203   84301    1  15607458  15671057    215      18  618929  5.5125
# 204    6248    1  15649869  15671722     63      10  625701  5.6159
# 205   23207    1  15674267  15744769    299      32  623320  6.6035
# 465  127550    1  33296766  33331098    137      27  614472  4.6316
#
#                 P GENE_NAME
# 202  4.195900e-07     AGMAT
# 203  1.769100e-08      DDI2
# 204  9.774400e-09    RSC1A1
# 205  2.008100e-11   PLEKHM2
# 465  1.814100e-06   A3GALT2
# importing file: network_scores/gscan_dpw_magma_zscore.tsv
#                z
# 0
# UBE2Q1 -2.315852
# RNF14  -1.327797
# UBE2Q2 -2.279223
# TMCO1  -1.005582
# UBAC1  -0.676896

# %% [markdown]
# ## loop venn diagram seeds

# %%
for row_rare in range(len(rare_datasets)):
    #import rare seed gene list and NPS scores
    label_rare=rare_datasets['label'][row_rare]
    print('analyzing rare dataset: '+label_rare)
    seed_rare=import_seedgenes(path=rare_datasets['seed_path'][row_rare],
                               pcol=None,
                               gene_col=rare_datasets['seed_gene_name'],
                                delim=rare_datasets['delim'][row_rare])
    seed_rare=list(set(seed_rare[rare_datasets['seed_gene_name'][row_rare]]).intersection(interactome_nodes))
    for row_common in range(len(common_datasets)):
        label_common=common_datasets['label'][row_common]
        print('analyzing common dataset: '+label_common)
        seed_common=import_seedgenes(path=common_datasets['seed_path'][row_common],
                                    pcol=common_datasets['seed_p'][row_common], 
                                    gene_col=common_datasets['seed_gene_name'][row_common],
                                    delim=common_datasets['delim'][row_common],
                                    cutoff=common_datasets['cutoff'][row_common])
        seed_common=list(set(seed_common[common_datasets['seed_gene_name'][row_common]]).intersection(interactome_nodes))
        
        print('N rare seed genes- '+label_rare+': '+str(len(set(seed_rare))))
        print('N common seed genes- '+label_common+': '+str(len(set(seed_common))))
        print(set(seed_rare).intersection(set(seed_common)))

        venn_seeds(seed_rare,seed_common,label_rare, label_common, interactome_nodes)        
        plt.clf()
# Out:
# analyzing rare dataset: alcoholintake_FDR_25
# pvalue column not specified- all genes will be used
# cutoff not defined/custom- using all genes
#    Unnamed: 0 Gene Name
# 0           0      PMM2
# 1           1   SLC29A1
# 2           2     SCN7A
# 3           3    ATP2B1
# 4           4     MMEL1
# analyzing common dataset: GSCAN_DPW_magma
#        GENE  CHR     START      STOP  NSNPS  NPARAM       N   ZSTAT  \
# 202   79814    1  15561699  15595110    199      19  628831  4.9260
# 203   84301    1  15607458  15671057    215      18  618929  5.5125
# 204    6248    1  15649869  15671722     63      10  625701  5.6159
# 205   23207    1  15674267  15744769    299      32  623320  6.6035
# 465  127550    1  33296766  33331098    137      27  614472  4.6316
#
#                 P GENE_NAME
# 202  4.195900e-07     AGMAT
# 203  1.769100e-08      DDI2
# 204  9.774400e-09    RSC1A1
# 205  2.008100e-11   PLEKHM2
# 465  1.814100e-06   A3GALT2
# N rare seed genes- alcoholintake_FDR_25: 32
# N common seed genes- GSCAN_DPW_magma: 264
# {'ADH1B', 'ADH1C'}
# {'ADH1B', 'ADH1C'}

# %% [markdown]
# ## Loop network colocalization, and net coloc venn diagram

# %%
#set the Z-score cutoffs to calculate network enrichment significance
zlist = [1,2,3,5]
z12list = [1,1.5,2]

# %%
for row_rare in range(len(rare_datasets)):
    label_rare=rare_datasets['label'][row_rare]
    print('analyzing rare dataset: '+label_rare)
    #import rare seed gene list and NPS scores
    seed_rare=import_seedgenes(path=rare_datasets['seed_path'][row_rare],
                               pcol=None,
                               gene_col=rare_datasets['seed_gene_name'],
                                delim=rare_datasets['delim'][row_rare])
    seed_rare=list(set(seed_rare[rare_datasets['seed_gene_name'][row_rare]]))
    zscore_rare_df=import_nps_zscores(z_path=rare_datasets['zscore_path'][row_rare], interactome_name='pcnet_v14')
    for row_common in range(len(common_datasets)):
        label_common=common_datasets['label'][row_common]
        print('analyzing common dataset: '+label_common)
        #import common seed gene list and NPS scores
        seed_common=import_seedgenes(path=common_datasets['seed_path'][row_common],
                                    pcol=common_datasets['seed_p'][row_common], 
                                    gene_col=common_datasets['seed_gene_name'][row_common],
                                    delim=common_datasets['delim'][row_common],
                                    cutoff=common_datasets['cutoff'][row_common])
        zscore_common_df=import_nps_zscores(z_path=common_datasets['zscore_path'][row_common], interactome_name='pcnet_v14')
        #calculate network enrichment
        netcoloc_enrichment_df = network_colocalization.calculate_network_enrichment(zscore_rare_df,zscore_common_df,
                                                                                     zthresh_list = zlist,
                                                                                     z12thresh_list=z12list,
                                                                                     verbose=False)
        netcoloc_enrichment_df=netcoloc_enrichment_df[netcoloc_enrichment_df['z_comb']>=netcoloc_enrichment_df['z_12']]
        print(netcoloc_enrichment_df)
        if save_fig:
            netcoloc_enrichment_df.to_csv('colocalization_scores/colocScore_'+label_common+'_'+label_common+UUID_tag[interactome_name]+'.tsv',sep='\t')
        
        pOverlap=float(netcoloc_enrichment_df[(netcoloc_enrichment_df['z_comb']==cutoff_comb) & (netcoloc_enrichment_df['z_12']==cutoff_single)]['empirical_p'])
        #plot venn diagram of network overlap
        venn_net(zscore_rare_df['z'].squeeze(), zscore_common_df['z'].squeeze(), label_rare, label_common, pOverlap, save_fig)
        
        plt.clf()
# Out:
# analyzing rare dataset: alcoholintake_FDR_25
# pvalue column not specified- all genes will be used
# cutoff not defined/custom- using all genes
#    Unnamed: 0 Gene Name
# 0           0      PMM2
# 1           1   SLC29A1
# 2           2     SCN7A
# 3           3    ATP2B1
# 4           4     MMEL1
# importing file: network_scores/alcoholintake_fdr_25_zscore.tsv
#                z
# 0
# UBE2Q1 -0.900155
# RNF14  -1.262321
# UBE2Q2 -0.826430
# TMCO1  -1.503556
# UBAC1   0.528793
# analyzing common dataset: GSCAN_DPW_magma
#        GENE  CHR     START      STOP  NSNPS  NPARAM       N   ZSTAT  \
# 202   79814    1  15561699  15595110    199      19  628831  4.9260
# 203   84301    1  15607458  15671057    215      18  618929  5.5125
# 204    6248    1  15649869  15671722     63      10  625701  5.6159
# 205   23207    1  15674267  15744769    299      32  623320  6.6035
# 465  127550    1  33296766  33331098    137      27  614472  4.6316
#
#                 P GENE_NAME
# 202  4.195900e-07     AGMAT
# 203  1.769100e-08      DDI2
# 204  9.774400e-09    RSC1A1
# 205  2.008100e-11   PLEKHM2
# 465  1.814100e-06   A3GALT2
# importing file: network_scores/gscan_dpw_magma_zscore.tsv
#                z
# 0
# UBE2Q1 -2.315852
# RNF14  -1.327797
# UBE2Q2 -2.279223
# TMCO1  -1.005582
# UBAC1  -0.676896
#     z_comb  z_12  observed_overlap  expected_overlap_mean  \
# 0        1   1.0               571                 456.07
# 3        2   1.0               435                 346.39
# 4        2   1.5               223                 161.78
# 5        2   2.0                79                  57.02
# 6        3   1.0               299                 229.78
# 7        3   1.5               208                 147.43
# 8        3   2.0                79                  56.24
# 9        5   1.0               140                 113.63
# 10       5   1.5               111                  84.99
# 11       5   2.0                68                  50.52
#
#     expected_overlap_std   empirical_p   obs_exp
# 0              18.758068  4.478594e-10  1.252001
# 3              16.736723  5.972161e-08  1.255810
# 4              11.110878  1.795027e-08  1.378415
# 5               7.640654  2.009179e-03  1.385479
# 6              13.301564  9.757484e-08  1.301245
# 7               9.476555  8.209931e-11  1.410839
# 8               6.758876  3.793697e-04  1.404694
# 9               9.333440  2.361635e-03  1.232069
# 10              8.376748  9.513188e-04  1.306036
# 11              6.907214  5.691959e-03  1.346002

# %% [markdown]
# ## Loop generating networks- save to ndexbio - has to be run on networkx version for python 3.8- outputs gibberish network for python 3.6 version

# %%
for row_rare in range(len(rare_datasets)):
    label_rare=rare_datasets['label'][row_rare]
    print('analyzing rare dataset: '+label_rare)
    #import rare seed gene list and NPS scores
    seed_rare=import_seedgenes(path=rare_datasets['seed_path'][row_rare],
                               pcol=None,
                               gene_col=rare_datasets['seed_gene_name'],
                                delim=rare_datasets['delim'][row_rare])
    seed_rare=list(set(seed_rare[rare_datasets['seed_gene_name'][row_rare]]))
    zscore_rare_df=import_nps_zscores(z_path=rare_datasets['zscore_path'][row_rare], interactome_name='pcnet_v14')
    for row_common in range(len(common_datasets)):
        label_common=common_datasets['label'][row_common]
        print('analyzing common dataset: '+label_common)
        #import common seed gene list and NPS scores
        seed_common=import_seedgenes(path=common_datasets['seed_path'][row_common],
                                    pcol=common_datasets['seed_p'][row_common], 
                                    gene_col=common_datasets['seed_gene_name'][row_common],
                                    delim=common_datasets['delim'][row_common],
                                    cutoff=common_datasets['cutoff'][row_common])
        zscore_common_df=import_nps_zscores(z_path=common_datasets['zscore_path'][row_common], interactome_name='pcnet_v14')

        #generate subgraph
        net=network_colocalization.calculate_network_overlap_subgraph(interactome, zscore_rare_df['z'].squeeze(), zscore_common_df['z'].squeeze(), cutoff_comb, cutoff_single, cutoff_single)
        net2=format_network(net, label_rare, label_common, seed_rare , seed_common, zscore_rare_df['z'].squeeze(), zscore_common_df['z'].squeeze())
        print(net2.nodes())
        if save_fig:
            print('exporting network to NDEx')
            export_network(network=net, name=(label_rare+'_'+label_common+'_'+UUID_tag[interactome_name]), user=ndex_user, password=ndex_password)
# Out:
# analyzing rare dataset: alcoholintake_FDR_25
# pvalue column not specified- all genes will be used
# cutoff not defined/custom- using all genes
#    Unnamed: 0 Gene Name
# 0           0      PMM2
# 1           1   SLC29A1
# 2           2     SCN7A
# 3           3    ATP2B1
# 4           4     MMEL1
# importing file: network_scores/alcoholintake_fdr_25_zscore.tsv
#                z
# 0
# UBE2Q1 -0.900155
# RNF14  -1.262321
# UBE2Q2 -0.826430
# TMCO1  -1.503556
# UBAC1   0.528793
# analyzing common dataset: GSCAN_DPW_magma
#        GENE  CHR     START      STOP  NSNPS  NPARAM       N   ZSTAT  \
# 202   79814    1  15561699  15595110    199      19  628831  4.9260
# 203   84301    1  15607458  15671057    215      18  618929  5.5125
# 204    6248    1  15649869  15671722     63      10  625701  5.6159
# 205   23207    1  15674267  15744769    299      32  623320  6.6035
# 465  127550    1  33296766  33331098    137      27  614472  4.6316
#
#                 P GENE_NAME
# 202  4.195900e-07     AGMAT
# 203  1.769100e-08      DDI2
# 204  9.774400e-09    RSC1A1
# 205  2.008100e-11   PLEKHM2
# 465  1.814100e-06   A3GALT2
# importing file: network_scores/gscan_dpw_magma_zscore.tsv
#                z
# 0
# UBE2Q1 -2.315852
# RNF14  -1.327797
# UBE2Q2 -2.279223
# TMCO1  -1.005582
# UBAC1  -0.676896
# ['STAM2', 'SH3BP4', 'OTUD6B', 'RAD23A', 'HSP90AA1', 'PTEN', 'MLF1', 'SECISBP2L', 'ERBIN', 'ADH5', 'LIMA1', 'DNAJB14', 'TANC2', 'CHRNB2', 'GLYAT', 'ZBTB18', 'BBLN', 'ADGRG5', 'INPPL1', 'GOLGA6B', 'MNS1', 'NECAB3', 'PKLR', 'ATG101', 'SND1', 'SLC5A6', 'MLX', 'KPNA5', 'ACACB', 'SLC35A2', 'STT3A', 'TRMT6', 'ALDH3B1', 'PTGR1', 'CYP3A5', 'GIT1', 'GIT2', 'UGT2B7', 'ALDH2', 'NAGPA', 'PM20D1', 'CKB', 'ALDH1A2', 'AKR1A1', 'ACO1', 'ALDH6A1', 'DNMT3A', 'MPP3', 'GABPB1', 'TGFB2', 'PRKAR2A', 'ACSS1', 'SBK1', 'TXK', 'ULK3', 'SMG1', 'EXOC2', 'LINS1', 'CEP85L', 'TENT2', 'FAF1', 'C1orf109', 'ESD', 'SNRPC', 'CPSF4', 'HIPK3', 'KIAA2026', 'TTC21B', 'FGF3', 'SLC24A2', 'CACNG4', 'DLGAP4', 'SPTBN1', 'CYP2E1', 'CACNB3', 'CELF1', 'PCMTD1', 'TELO2', 'CDK8', 'GRK6', 'MECP2', 'TP53I3', 'ADIPOQ', 'ALDH3A1', 'FOXP2', 'FOXP1', 'FOXP4', 'ARHGAP26', 'ADH6', 'RABEP2', 'DTNA', 'KDM8', 'DNAH8', 'ZNF483', 'NFAT5', 'YEATS4', 'ALDH1A1', 'CELSR3', 'ALDH1A3', 'ABCG2', 'CASQ2', 'TRPM7', 'LDHAL6A', 'CYP2A13', 'DDX6', 'SLC4A8', 'SYNJ2', 'ADH7', 'HBA2', 'KANK1', 'CD24', 'ADH1B', 'SULT1A2', 'ZBTB21', 'DOCK9', 'VAT1L', 'DYM', 'ADGRL1', 'GDF10', 'SH3YL1', 'CYP3A43', 'CYP2B6', 'CYP2C18', 'DNAJB12', 'ADGRG6', 'FMO3', 'TRPM4', 'PRKAB2', 'SULT1A1', 'MASP2', 'ZKSCAN5', 'RASA3', 'INHBC', 'LRATD2', 'ZKSCAN1', 'DHRS3', 'MECR', 'SCRN3', 'TRIM45', 'SPAG8', 'HHIPL2', 'ADH1A', 'RGN', 'ADHFE1', 'AADAC', 'UGT2B15', 'ADH4', 'TESMIN', 'PSD2', 'TMTC1', 'ECRG4', 'NRROS', 'BCKDHB', 'ZNF394', 'NKX6-2', 'ZBTB8B', 'ZNF215', 'SRXN1', 'UGT2B4', 'ZSCAN32', 'SNTB1', 'RTN2', 'UGT1A10', 'NLGN2', 'KCNE2', 'PANK2', 'ZNF397', 'MLXIPL', 'CA14', 'EEF2K', 'EPM2A', 'FOXR2', 'AKAP7', 'PDE4DIP', 'LDHD', 'GTF2IRD2', 'ABRACL', 'PGBD1', 'ZBED9-AS1', 'AWAT2', 'UGT3A2', 'CCDC71', 'UGT2A3', 'UGT1A8', 'UGT1A9', 'UGT1A5', 'UGT1A4', 'UGT1A7', 'UGT1A1', 'UGT1A6', 'UGT1A3', 'UGT2B17', 'UGT2B10', 'XYLT1', 'UGT2B28', 'DNAJC25-GNG10', 'PPP1R9A', 'ZSCAN25', 'MGST1', 'PHLPP2', 'KIFC2', 'PTGR2', 'UGT2A1', 'APOC4', 'ADH1C', 'KIF12', 'LRRC37A2', 'VSIG10']

# %%
# Import required libraries
import os
os.chdir('/home/bsleger/bsl/CrossSpeciesBMI')
import sys
import ndex2
from getpass import getpass
import pandas as pd
import mygene
mg = mygene.MyGeneInfo()
from netcoloc import netprop_zscore, netprop
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib_venn import venn2, venn3
import ddot

# Import functions specific to this study
os.chdir('/home/bsleger/bsl/CrossSpeciesBMI')
from updated_netcoloc_functions import *
from analysis_functions import *
from plotting_functions import *
os.chdir('/home/bsleger/bsl/rare_common_alcohol')
# Set up directory paths. Defaults to the Data/ and Figures/ folders within the repository.
#cwd = os.path.dirname('/home/bsleger/bsl/CrossSpeciesBMI')
path="/home/bsleger/bsl/rare_common_alcohol/"
DATADIR = os.path.join(path)
FIGDIR = os.path.join(path, "figures/")

# %%
#loop over all rare and common
#plot network enrichment histograms

zlist = [1,1.5,2,3,4,5]
z12list = [1,1.5,2,3,4,5]

cutoff_single=1.5
cutoff_comb=3
for row_rare in range(len(rare_datasets)):
    if (rare_datasets['delim'][row_rare]=='comma'):
        seed_rare=pd.read_csv(rare_datasets['seed_path'][row_rare],sep=',')
    else:
        seed_rare=pd.read_csv(rare_datasets['seed_path'][row_rare],sep='\t')    
    seed_rare=list(seed_rare[rare_datasets['seed_gene_name'][row_rare]])
    seed_rare=list(set(seed_rare))
    label_rare=rare_datasets['label'][row_rare]
    if interactome_name=='pcnet_v14':
        zscore_rare_df=pd.read_csv(rare_datasets['zscore_path'][row_rare],header=None, sep='\t')
    else:
        z_path=rare_datasets['zscore_path'][row_rare]
        z_path_head=z_path[0:len(z_path)-11:1]
        z_path_tail=z_path[len(z_path)-11:len(z_path):1]
        print(z_path_head+'_'+interactome_name+z_path_tail)
        zscore_rare_df=pd.read_csv(z_path_head+'_'+interactome_name+z_path_tail,header=None, sep='\t')
    zscore_rare_df.index=zscore_rare_df[0]
    zscore_rare_df=zscore_rare_df.drop(columns=[0])
    zscore_rare=zscore_rare_df[1].squeeze()
    zscore_rare_df = pd.DataFrame({'z':zscore_rare})
    print('analyzing '+rare_datasets['label'][row_rare])
    for row_common in range(len(common_datasets)):

        print('analyzing '+common_datasets['label'][row_common])
        #common variants
        #common_datasets[''][row_common]
        label_common=common_datasets['label'][row_common]
        if (common_datasets['delim'][row_common]=='tab'):
            seed_common=pd.read_csv(common_datasets['seed_path'][row_common],sep='\t')
        else:
            seed_common=pd.read_csv(common_datasets['seed_path'][row_common],sep=',')
        if(common_datasets['cutoff'][row_common]=='bonferroni'):
            print('using bonferroni')
            seed_common=seed_common[seed_common[common_datasets['seed_p'][row_common]]<0.05/len(seed_common)]
        elif(common_datasets['cutoff'][row_common]=='lead_snps'):
            print('using no cutoff')
        else:
            print('using no cutoff')
        seed_common=list(seed_common[common_datasets['seed_gene_name'][row_common]])
        
        if interactome_name=='pcnet_v14':
            zscore_common_df=pd.read_csv(common_datasets['zscore_path'][row_common],header=None, sep='\t')
        else:
            z_path=common_datasets['zscore_path'][row_common]
            z_path_head=z_path[0:len(z_path)-11:1]
            z_path_tail=z_path[len(z_path)-11:len(z_path):1]
            zscore_common_df=pd.read_csv(z_path_head+'_'+interactome_name+z_path_tail,header=None, sep='\t')

        
        zscore_common_df.index=zscore_common_df[0]
        zscore_common_df=zscore_common_df.drop(columns=[0])
        zscore_common=zscore_common_df[1].squeeze()
        zscore_common_df = pd.DataFrame({'z':zscore_common})
        
        seed_rare=list(set(seed_rare).intersection(G_PC))
        seed_common=list(set(seed_common).intersection(G_PC))
        
        # Generate a null distribution of colocalized network size by shuffling the z_scores and applying the thresholds:
        # NPS_r > 1, NPS_h > 1, NPS_hr > 3
        cutoff_single=1.5
        cutoff_comb=3
        observed_sz, permuted_sz = calculate_expected_overlap(zscore_common_df, zscore_rare_df, 
                                                                    z_score_threshold=cutoff_comb, z1_threshold=cutoff_single,
                                                                    z2_threshold=cutoff_single, num_reps=10000, plot=False, 
                                                                    overlap_control="bin",
                                                                    seed1=seed_common, seed2=seed_rare)

        plot_permutation_histogram(permuted_sz, observed_sz,'', 'Size of colocalized network', color="#cccccc",
                          arrow_color="#3636eb")

        #plt.savefig(FIGDIR + rare_label+"_"+common_label+"netcoloc_size_histogram_500dpi.png",dpi=500, bbox_inches="tight")
        plt.savefig(FIGDIR + label_rare+"_"+label_common+UUID_tag[interactome_name]+"netcoloc_size_histogram.svg", bbox_inches="tight")
        plt.clf() 
        
        # Generate a null distribution of mean NPS by shuffling the z_scores. Note, due to randomization this distribution will not be exactly the same as the reported result
        observed_net, permuted_net = calculate_mean_z_score_distribution(zscore_common_df, zscore_rare_df, num_reps=10000,
                                                                zero_double_negatives=False, overlap_control="bin",
                                                                seed1=seed_common, seed2=seed_rare)
        plot_permutation_histogram(permuted_net, observed_net,'', 'Mean $NPS_{common-rare}$',color="#cccccc",arrow_color="#3636eb")
        plt.savefig(FIGDIR + label_rare+"_"+label_common+UUID_tag[interactome_name]+"mean_NPS_histogram.svg", bbox_inches="tight")
        plt.clf()
    plt.clf()
